# %% [markdown]
# <a href="https://colab.research.google.com/github/rondony/Desaf-o-sugerencia-3-v-deos/blob/main/001_clase_abierta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Primera sesión abierta: 100 estudiantes más avanzados
#
# La iniciativa, ejecutada por ONG Innovacien, busca democratizar el acceso al código a través de un “Curso Abierto” intensivo de 50 horas, modalidad 100% flexible y sin requisitos previos de ingreso.
#
# ![KV-Oficial-Sic-2026_Logo.png](data:image/png;base64,...)

# %%
1 + 1
# Out:
# 2

# %%
datos_alumno = """
Nombre: Yonny Rondón.
Edad: 50
Profesión: Abogado e Ing. administración
Domicilio: Novena Region De La Araucanía,
Comuna de Temuco
Breve descripción: Postulé al curso de INNOVACIEN,
porque quiero aprender más a profundidad Python.
Actualmente estudio Técnico analista Programador en el INACAP.
"""
print(datos_alumno)
# Out:
# Nombre: Yonny Rondón.
# Edad: 50
# Profesión: Abogado e Ing. administración
# Domicilio: Novena Region De La Araucanía,
# Comuna de Temuco
# Breve descripción: Postulé al curso de INNOVACIEN,
# porque quiero aprender más a profundidad Python.
# Actualmente estudio Técnico analista Programador en el INACAP.
